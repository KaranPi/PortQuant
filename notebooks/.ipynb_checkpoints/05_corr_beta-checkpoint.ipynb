# %%
# Rolling mean/std quantify local drift and variability; pairing with z-scores makes cross-asset comparability easy.

# Skew/kurtosis capture shape (asymmetry & tail thickness) — crucial for understanding why Normal VaR can underestimate risk.

# Correlation is the backbone for aggregation and portfolio construction; forcing a minimum overlap avoids unstable pair estimates from tiny samples.

# %%
# Rolling β shows regime shifts (e.g., changing market exposure).

# %%
# --- Make local package importable (robust for notebooks in subfolders) ---
import sys
from pathlib import Path

def add_src_to_path(pkg="quantlib", levels_up=3):
    here = Path.cwd().resolve()
    candidates = [here / "src"]
    # also check parents: ../src, ../../src, ...
    for i in range(1, levels_up+1):
        candidates.append(here.parents[i-1] / "src")
    for p in candidates:
        if (p / pkg / "__init__.py").exists():
            sys.path.insert(0, str(p))
            print(f"[OK] Added to sys.path: {p}")
            return p
    raise FileNotFoundError("Could not find src/quantlib/__init__.py relative to this notebook.")

add_src_to_path()
# Out:
# [OK] Added to sys.path: C:\Users\quantbase\Desktop\quant\src
# WindowsPath('C:/Users/quantbase/Desktop/quant/src')

# %%
# 05_corr_beta.ipynb
import sys, pathlib; sys.path.append(str(pathlib.Path.cwd() / "src"))
from pathlib import Path
import pandas as pd
import numpy as np
from quantlib import stats as qstat
import importlib, quantlib.viz as qviz
from quantlib import factors as qfac

#DATA_INT = Path(r"C:\Users\quantbase\Desktop\quant\data_int")
#FIG_DIR = Path(r"C:\Users\quantbase\Desktop\quant\figures"); FIG_DIR.mkdir(exist_ok=True, parents=True)

# %%
#from pathlib import Path

def get_index_name(int_dir: Path, panel_cols) -> str:
    """Try meta file, else regex heuristic among panel columns."""
    meta = int_dir / "index_meta.txt"
    if meta.exists():
        txt = meta.read_text(encoding="utf-8").strip()
        if txt and txt in panel_cols:
            return txt
    # Heuristic: look for NIFTY* / BANKNIFTY* etc.
    import re
    pats = [r'^NIFTY\d*$', r'^BANKNIFTY\d*$', r'^NIFTYBANK$', r'^NIFTY500$', r'^NIFTYMIDCAP\d*$']
    for c in panel_cols:
        up = str(c).upper().replace(" ", "")
        if any(re.match(p, up) for p in pats):
            return c
    return ""

# %%
ROOT = Path(r"C:\Users\quantbase\Desktop\quant")
RUN_DATE = "30-09-2025"  # <- set this for the run you want to analyze
RUN_DIR  = ROOT / RUN_DATE
DATA_INT = RUN_DIR / "data_int"
DATA_RAW = RUN_DIR / "data_raw"
FIG_DIR = RUN_DIR/ "figures"

prices_close = pd.read_pickle(DATA_INT / "prices_close_anchor_leftjoin_with_index.pkl").sort_index()

# %%
# --- compute full-sample correlation (min overlap 126) & plot ---
r_1d = pd.read_pickle(DATA_INT / "log_returns_daily_all.pkl").sort_index()
r_5d = pd.read_pickle(DATA_INT / "log_returns_trailing_all_w5.pkl").sort_index()
r_21d = pd.read_pickle(DATA_INT / "log_returns_trailing_all_w21.pkl").sort_index()
r_63d = pd.read_pickle(DATA_INT / "log_returns_trailing_all_w63.pkl").sort_index()
r_252d = pd.read_pickle(DATA_INT / "log_returns_trailing_all_w252.pkl").sort_index()

# %%
corr = qstat.corr_full(r_1d, min_obs=200)
corr.to_pickle(DATA_INT/"corr_full_1d.pkl")

# %%
qviz.plot_corr_heatmap(corr, title="Daily return correlation (min overlap 200)", save_path=FIG_DIR/"corr_daily.png")
# Out:
# C:\Users\quantbase\Desktop\quant\src\quantlib\viz.py:234: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("RdBu_r"))
#   cmap.set_bad(color="#f0f0f0")

# %%
corr = qstat.corr_full(r_5d, min_obs=200)
corr.to_pickle(DATA_INT/"corr_full_5d.pkl")

# %%
qviz.plot_corr_heatmap(corr, title="5D return correlation (min overlap 200)", save_path=FIG_DIR/"corr_5d.png")
# Out:
# C:\Users\quantbase\Desktop\quant\src\quantlib\viz.py:234: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("RdBu_r"))
#   cmap.set_bad(color="#f0f0f0")

# %%
corr = qstat.corr_full(r_21d, min_obs=200)
corr.to_pickle(DATA_INT/"corr_full_21d.pkl")

qviz.plot_corr_heatmap(corr, title="21D return correlation (min overlap 200)", save_path=FIG_DIR/"corr_21d.png")

# %%
corr = qstat.corr_full(r_63d, min_obs=200)
corr.to_pickle(DATA_INT/"corr_full_63d.pkl")

qviz.plot_corr_heatmap(corr, title="63D return correlation (min overlap 200)", save_path=FIG_DIR/"corr_63d.png")

# %%
corr = qstat.corr_full(r_252d, min_obs=200)
corr.to_pickle(DATA_INT/"corr_full_252d.pkl")

qviz.plot_corr_heatmap(corr, title="252D return correlation (min overlap 200)", save_path=FIG_DIR/"corr_252d.png")

# %%
# --- beta: pick an index proxy column present in r_1d ---
INDEX_COL = "NIFTY50"  
beta_full = qstat.beta_against_index(r_1d, index_col=INDEX_COL, window=None)
display(beta_full.T.sort_values("full_sample", ascending=False).head(60))
beta_full.to_csv(DATA_INT/"beta_full_1d.csv")
# Out:
#             full_sample
# ADANIENT       1.698365
# HFCL           1.670784
# ADANIPORTS     1.590421
# IRCTC          1.565797
# BHEL           1.535483
# KELLTONTEC     1.523568
# IREDA          1.434210
# TATAPOWER      1.389870
# MAZDOCK        1.289146
# ZOMATO         1.272715
# SBIN           1.257505
# IEX            1.254106
# IDFCFIRSTB     1.250666
# VINCOFE        1.247262
# SPANDANA       1.237280
# BANDHANBNK     1.202625
# RAILTEL        1.184696
# WAAREERTL      1.176090
# RVNL           1.173370
# MANINDS        1.163789
# HAL            1.142563
# HDFCBANK       1.135104
# PPL            1.120447
# JIOFIN         1.115486
# MCX            1.112271
# FEDERALBNK     1.111564
# CDSL           1.110819
# AXISBANK       1.110584
# LATENTVIEW     1.108978
# PREMIERENE     1.104056
# SWIGGY         1.081993
# DATAPATTNS     1.069711
# INDIGO         1.059231
# AEROFLEX       1.058232
# BAJFINANCE     1.046910
# COALINDIA      1.029096
# NEWGEN         1.025958
# ...

# %%
beta_full = qstat.beta_against_index(r_5d, index_col=INDEX_COL, window=None)
display(beta_full.T.sort_values("full_sample", ascending=False).head(60))
beta_full.to_csv(DATA_INT/"beta_full_5d.csv")
# Out:
#             full_sample
# IREDA          1.934330
# KELLTONTEC     1.837274
# PREMIERENE     1.789356
# IRCTC          1.711950
# HFCL           1.708667
# BHEL           1.650610
# VINCOFE        1.584119
# SPANDANA       1.541032
# ADANIENT       1.527538
# RVNL           1.498985
# LATENTVIEW     1.490003
# ADANIPORTS     1.486603
# TATAPOWER      1.464414
# MAZDOCK        1.459583
# BAJFINANCE     1.442185
# DATAPATTNS     1.425996
# RTNPOWER       1.418688
# RAILTEL        1.416627
# CDSL           1.356713
# DCXINDIA       1.330556
# HAL            1.314166
# ZOMATO         1.311781
# SBIN           1.306809
# WAAREERTL      1.301177
# BANDHANBNK     1.269982
# MANINDS        1.249878
# HDFCBANK       1.239703
# PPL            1.225168
# NEWGEN         1.220733
# IDFCFIRSTB     1.219065
# IEX            1.210322
# AEROFLEX       1.208194
# UJJIVANSFB     1.189579
# JIOFIN         1.179545
# PRINCEPIPE     1.177152
# INDIGO         1.172118
# FEDERALBNK     1.168145
# ...

# %%
beta_full = qstat.beta_against_index(r_21d, index_col=INDEX_COL, window=None)
display(beta_full.T.sort_values("full_sample", ascending=False).head(60))
beta_full.to_csv(DATA_INT/"beta_full_21d.csv")
# Out:
#             full_sample
# KELLTONTEC     2.347332
# HFCL           2.313371
# RTNPOWER       2.304740
# MAZDOCK        2.296832
# IEX            2.141494
# IRCTC          2.077161
# DATAPATTNS     1.987852
# RVNL           1.856947
# BHEL           1.821070
# DCXINDIA       1.780496
# RAILTEL        1.728820
# HAL            1.726104
# ADANIENT       1.617400
# IREDA          1.588730
# IDFCFIRSTB     1.498078
# TATAPOWER      1.496342
# LATENTVIEW     1.482004
# ADANIPORTS     1.438644
# PREMIERENE     1.438113
# TATAELXSI      1.420201
# ZOMATO         1.411491
# NEWGEN         1.392873
# SPANDANA       1.371786
# JIOFIN         1.355601
# COCHINSHIP     1.344247
# SBIN           1.283098
# INDIGO         1.283097
# MANINDS        1.279498
# AXISBANK       1.246524
# VINCOFE        1.237345
# PRINCEPIPE     1.235112
# IRFC           1.230373
# CDSL           1.211863
# BAJFINANCE     1.171975
# CLEAN          1.160443
# HAPPSTMNDS     1.134641
# WHIRLPOOL      1.121888
# ...

# %%
beta_full = qstat.beta_against_index(r_63d, index_col=INDEX_COL, window=None)
display(beta_full.T.sort_values("full_sample", ascending=False).head(60))
beta_full.to_csv(DATA_INT/"beta_full_63d.csv")
# Out:
#             full_sample
# RTNPOWER       3.395837
# MAZDOCK        3.314908
# DCXINDIA       2.854833
# VINCOFE        2.753508
# IRCTC          2.721105
# IEX            2.584948
# HFCL           2.535333
# ZOMATO         2.530979
# JIOFIN         2.530764
# DATAPATTNS     2.430891
# ADANIENT       2.394139
# IREDA          2.389233
# CDSL           2.346882
# BHEL           2.290473
# RAILTEL        2.275633
# RVNL           2.212857
# MANINDS        2.170085
# NEWGEN         1.902299
# HAL            1.900152
# HAPPSTMNDS     1.898098
# IRFC           1.886324
# ADANIPORTS     1.875919
# INOXINDIA      1.846626
# TATAPOWER      1.822037
# SPANDANA       1.762260
# SWIGGY         1.755965
# PRINCEPIPE     1.690436
# DMART          1.625913
# WHIRLPOOL      1.617067
# LATENTVIEW     1.601419
# IDFCFIRSTB     1.590751
# MTARTECH       1.562957
# SONACOMS       1.498819
# MCX            1.413587
# INDIGO         1.354813
# CASTROLIND     1.319500
# TATAELXSI      1.296661
# ...

# %%
beta_full = qstat.beta_against_index(r_252d, index_col=INDEX_COL, window=None)
display(beta_full.T.sort_values("full_sample", ascending=False).head(60))
beta_full.to_csv(DATA_INT/"beta_full_252d.csv")
# Out:
#             full_sample
# ZOMATO         6.550442
# IRFC           5.711981
# KELLTONTEC     5.140457
# RAILTEL        5.083027
# BHEL           4.235936
# IRCTC          4.010147
# IEX            3.870148
# CDSL           3.860058
# SPANDANA       3.791490
# RVNL           3.681614
# NEWGEN         3.580070
# PPL            3.547622
# BAJFINANCE     3.133453
# HFCL           3.071251
# MANINDS        2.859660
# TATAPOWER      2.856355
# SONACOMS       2.650717
# MCX            2.582125
# ADANIPORTS     2.474696
# PRINCEPIPE     2.442520
# MAZDOCK        2.422007
# RTNPOWER       2.246715
# CASTROLIND     2.188432
# LATENTVIEW     2.180969
# INDIGO         1.934417
# COCHINSHIP     1.727441
# TATACONSUM     1.662894
# COALINDIA      1.550752
# DMART          1.500031
# WHIRLPOOL      1.275833
# DATAPATTNS     1.275287
# IDFCFIRSTB     1.257350
# SBIN           1.228460
# HAPPSTMNDS     1.186018
# CLEAN          1.179167
# TATAELXSI      1.146904
# MTARTECH       1.118913
# ...

# %%
# CAPM-----------------------

# %%
# Load daily log returns that INCLUDE the index column (e.g. 'NIFTY50')

index_col = "NIFTY50"   # adjust if your column name differs

# A basket example (or omit cols=... to use all)
basket = [
    "NEWGEN",
    "UJJIVANSFB",
    "RVNL",
    "TATACONSUM",
    "DATAPATTNS",
    "BAJFINANCE",
    "AVALON",
    "MCX",
    "INDIGO",          # InterGlobe Aviation
    "IRFC",
    "HDFCBANK",
    "DMART",           # Avenue Supermarts
    "AXISBANK",
    "CDSL",            # Central Depository Services
    "IRCTC",
    "ADANIPORTS",
    "ZOMATO",          # “Eternal (Zomato)” → using ZOMATO symbol
    "INOXINDIA",
    "ACI",             # Archean Chem Inds
    "MAZDOCK",
    "SWIGGY",
    "SYNGENE",
    "PPL",             # Prakash Pipes
    "AEROFLEX",
    "IDFCFIRSTB",
    "VINCOFE",         # Vintage Coffee
    "KOTAKBANK",
    "SBICARD",
    "ADANIENT",
    "SBIN",
    "JIOFIN",
    "CASTROLIND",
    "HAPPSTMNDS",
    "HAL",
    "FEDERALBNK",
    "IREDA",           # India Renewable Energy Dev. Agency
    "WAAREERTL",
    "TATAPOWER",
    "KELLTONTEC",
    "PREMIERENE",
    "CLEAN",           # Clean Science
    "COALINDIA",
    "RTNPOWER",
    "BHEL",
    "WHIRLPOOL",
    "VBL",             # Varun Beverages
    "LATENTVIEW",
    "BANDHANBNK",
    "HFCL",
    "AETHER",
    "SPANDANA",
    "SONACOMS",        # Sona BLW Precision
    "IEX",
    "DCXINDIA",
    "MTARTECH",
    "TATAELXSI",
    "PRINCEPIPE",
    "RAILTEL",          # Returns are not available:
    "MANINDS",        # MAN Industries
    "COCHINSHIP",
    "NIFTY50"
]  # index will be excluded automatically

# %%
tbl = qfac.capm_decompose_table(r_5d, index_col=index_col,windows=(21,63), cols=basket)

# %%
tbl.to_csv(DATA_INT/"market_beta_5d.csv")

# %%
tbl = qfac.capm_decompose_table(r_21d, index_col=index_col,windows=(21,63), cols=basket)

# %%
tbl.head(100)
# Out:
#         symbol  window       R_s       R_m      beta   sys_ret     alpha
# 0          ACI      21  1.160062  0.210615  1.138700  0.239827  0.920235
# 1     ADANIENT      21  0.847964  0.210615  2.854144  0.601125  0.246839
# 2   ADANIPORTS      21  0.630035  0.210615  2.697112  0.568052  0.061983
# 3     AEROFLEX      21 -0.136211  0.210615  2.035988  0.428809 -0.565020
# 4       AETHER      21 -0.355978  0.210615  0.632175  0.133146 -0.489123
# ..         ...     ...       ...       ...       ...       ...       ...
# 95     MAZDOCK      63 -3.171614 -0.037459  3.139529 -0.117603 -3.054011
# 96         MCX      63 -0.070586 -0.037459  3.370972 -0.126272  0.055686
# 97    MTARTECH      63 -0.495138 -0.037459  1.242773 -0.046553 -0.448585
# 98      NEWGEN      63 -6.144524 -0.037459  3.744423 -0.140261 -6.004263
# 99         PPL      63 -4.932548 -0.037459  1.046206 -0.039190 -4.893359
#
# [100 rows x 7 columns]

# %%
tbl.to_csv(DATA_INT/"market_beta_21d.csv")

# %%
tbl = qfac.capm_decompose_table(r_63d, index_col=index_col,windows=(21,63), cols=basket)
tbl.to_csv(DATA_INT/"market_beta_63d.csv")

# %%
tbl.head(50)
# Out:
#         symbol  window        R_s       R_m      beta   sys_ret      alpha
# 0          ACI      21   2.113781 -0.037459  0.814320 -0.030503   2.144284
# 1     ADANIENT      21  -0.926789 -0.037459  0.735849 -0.027564  -0.899225
# 2   ADANIPORTS      21  -0.507890 -0.037459  1.493292 -0.055937  -0.451953
# 3     AEROFLEX      21   0.106925 -0.037459  2.724843 -0.102069   0.208994
# 4       AETHER      21  -1.042493 -0.037459 -0.203379  0.007618  -1.050111
# 5       AVALON      21   2.528295 -0.037459 -0.254258  0.009524   2.518771
# 6     AXISBANK      21  -1.917595 -0.037459 -0.022266  0.000834  -1.918429
# 7   BAJFINANCE      21 -21.988859 -0.037459  1.212398 -0.045415 -21.943445
# 8   BANDHANBNK      21  -1.918518 -0.037459  1.728162 -0.064735  -1.853783
# 9         BHEL      21  -2.615022 -0.037459  1.428176 -0.053498  -2.561525
# 10  CASTROLIND      21  -1.457293 -0.037459  1.516371 -0.056801  -1.400492
# ...
