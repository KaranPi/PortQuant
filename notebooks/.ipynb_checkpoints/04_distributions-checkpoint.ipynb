# %%
# --- Make local package importable (robust for notebooks in subfolders) ---
import sys
from pathlib import Path

def add_src_to_path(pkg="quantlib", levels_up=3):
    here = Path.cwd().resolve()
    candidates = [here / "src"]
    # also check parents: ../src, ../../src, ...
    for i in range(1, levels_up+1):
        candidates.append(here.parents[i-1] / "src")
    for p in candidates:
        if (p / pkg / "__init__.py").exists():
            sys.path.insert(0, str(p))
            print(f"[OK] Added to sys.path: {p}")
            return p
    raise FileNotFoundError("Could not find src/quantlib/__init__.py relative to this notebook.")

add_src_to_path()
# Out:
# [OK] Added to sys.path: C:\Users\quantbase\Desktop\quant\src
# WindowsPath('C:/Users/quantbase/Desktop/quant/src')

# %%
# --- bootstrap & imports ---
import sys, pathlib; sys.path.append(str(pathlib.Path.cwd() / "src"))
from pathlib import Path
import pandas as pd
from quantlib import viz as qviz
#DATA_INT = Path(r"C:\Users\quantbase\Desktop\quant\data_int")
#FIG_DIR = Path(r"C:\Users\quantbase\Desktop\quant\figures"); FIG_DIR.mkdir(exist_ok=True, parents=True)

# %%
#from pathlib import Path

def get_index_name(int_dir: Path, panel_cols) -> str:
    """Try meta file, else regex heuristic among panel columns."""
    meta = int_dir / "index_meta.txt"
    if meta.exists():
        txt = meta.read_text(encoding="utf-8").strip()
        if txt and txt in panel_cols:
            return txt
    # Heuristic: look for NIFTY* / BANKNIFTY* etc.
    import re
    pats = [r'^NIFTY\d*$', r'^BANKNIFTY\d*$', r'^NIFTYBANK$', r'^NIFTY500$', r'^NIFTYMIDCAP\d*$']
    for c in panel_cols:
        up = str(c).upper().replace(" ", "")
        if any(re.match(p, up) for p in pats):
            return c
    return ""

# %%
#CHECK DATE


ROOT = Path(r"C:\Users\quantbase\Desktop\quant")
RUN_DATE = "30-09-2025"  # OR pd.Timestamp.today().normalize()
RUN_DIR  = ROOT / RUN_DATE
DATA_INT = RUN_DIR / "data_int"
FIG_DIR = RUN_DIR/ "figures"

prices_close = pd.read_pickle(DATA_INT / "prices_close_anchor_leftjoin.pkl")

# %%
SYMBOL = "NIFTY50"  # change as needed
ret_1d = pd.read_pickle(DATA_INT/"log_returns_daily_all.pkl")[SYMBOL]
ret_21 = pd.read_pickle(DATA_INT/"log_returns_trailing_all_w21.pkl")[SYMBOL]
ret_63 = pd.read_pickle(DATA_INT/"log_returns_trailing_all_w63.pkl")[SYMBOL]
ret_252 = pd.read_pickle(DATA_INT/"log_returns_trailing_all_w252.pkl")[SYMBOL]

qviz.plot_multi_tf_pdf(
    data={"1D": ret_1d.dropna(), "21D": ret_21.dropna(), "63D": ret_63.dropna(), "252D": ret_252.dropna()},
    title=f"{SYMBOL} — PDFs across horizons",
    show_kde=True, show_normal=False, show_student=False,
    save_path=FIG_DIR/f"pdf_{SYMBOL}.png"
)

# %%
# --- choose a symbol & gather horizons ---
SYMBOL = "MCX"  # change as needed
r_1d = pd.read_pickle(DATA_INT/"log_returns_daily_all.pkl")[SYMBOL]
r_21 = pd.read_pickle(DATA_INT/"log_returns_trailing_w21.pkl")[SYMBOL]
r_63 = pd.read_pickle(DATA_INT/"log_returns_trailing_w63.pkl")[SYMBOL]
r_252 = pd.read_pickle(DATA_INT/"log_returns_trailing_w252.pkl")[SYMBOL]

qviz.plot_multi_tf_pdf(
    data={"1D": r_1d.dropna(), "21D": r_21.dropna(), "63D": r_63.dropna(), "252D": r_252.dropna()},
    title=f"{SYMBOL} — PDFs across horizons",
    show_kde=True, show_normal=False, show_student=False,
    save_path=FIG_DIR/f"pdf_{SYMBOL}.png"
)

# %%
# --- choose a symbol & gather horizons ---
SYMBOL = "HDFCBANK"  # change as needed
r_1d = pd.read_pickle(DATA_INT/"log_returns_daily_all.pkl")[SYMBOL]
r_21 = pd.read_pickle(DATA_INT/"log_returns_trailing_w21.pkl")[SYMBOL]
r_63 = pd.read_pickle(DATA_INT/"log_returns_trailing_w63.pkl")[SYMBOL]
r_252 = pd.read_pickle(DATA_INT/"log_returns_trailing_w252.pkl")[SYMBOL]

qviz.plot_multi_tf_pdf(
    data={"1D": r_1d.dropna(), "21D": r_21.dropna(), "63D": r_63.dropna(), "252D": r_252.dropna()},
    title=f"{SYMBOL} — PDFs across horizons",
    show_kde=True, show_normal=False, show_student=False,
    save_path=FIG_DIR/f"pdf_{SYMBOL}.png"
)

# %%
# --- choose a symbol & gather horizons ---
SYMBOL = "SBIN"  # change as needed
r_1d = pd.read_pickle(DATA_INT/"log_returns_daily.pkl")[SYMBOL]
r_21 = pd.read_pickle(DATA_INT/"log_returns_trailing_w21.pkl")[SYMBOL]
r_63 = pd.read_pickle(DATA_INT/"log_returns_trailing_w63.pkl")[SYMBOL]
r_252 = pd.read_pickle(DATA_INT/"log_returns_trailing_w252.pkl")[SYMBOL]

qviz.plot_multi_tf_pdf(
    data={"1D": r_1d.dropna(), "21D": r_21.dropna(), "63D": r_63.dropna(), "252D": r_252.dropna()},
    title=f"{SYMBOL} — PDFs across horizons",
    show_kde=True, show_normal=False, show_student=False,
    save_path=FIG_DIR/f"pdf_{SYMBOL}.png"
)

# %%
# --- choose a symbol & gather horizons ---
SYMBOL = "BAJFINANCE"  # change as needed
r_1d = pd.read_pickle(DATA_INT/"log_returns_daily.pkl")[SYMBOL]
r_21 = pd.read_pickle(DATA_INT/"log_returns_trailing_w21.pkl")[SYMBOL]
r_63 = pd.read_pickle(DATA_INT/"log_returns_trailing_w63.pkl")[SYMBOL]
r_252 = pd.read_pickle(DATA_INT/"log_returns_trailing_w252.pkl")[SYMBOL]

qviz.plot_multi_tf_pdf(
    data={"1D": r_1d.dropna(), "21D": r_21.dropna(), "63D": r_63.dropna(), "252D": r_252.dropna()},
    title=f"{SYMBOL} — PDFs across horizons",
    show_kde=True, show_normal=False, show_student=False,
    save_path=FIG_DIR/f"pdf_{SYMBOL}.png"
)

# %%
# --- choose a symbol & gather horizons ---
SYMBOL = "AEROFLEX"  # change as needed
r_1d = pd.read_pickle(DATA_INT/"log_returns_daily.pkl")[SYMBOL]
r_21 = pd.read_pickle(DATA_INT/"log_returns_trailing_w21.pkl")[SYMBOL]
r_63 = pd.read_pickle(DATA_INT/"log_returns_trailing_w63.pkl")[SYMBOL]
r_252 = pd.read_pickle(DATA_INT/"log_returns_trailing_w252.pkl")[SYMBOL]

qviz.plot_multi_tf_pdf(
    data={"1D": r_1d.dropna(), "21D": r_21.dropna(), "63D": r_63.dropna(), "252D": r_252.dropna()},
    title=f"{SYMBOL} — PDFs across horizons",
    show_kde=True, show_normal=False, show_student=False,
    save_path=FIG_DIR/f"pdf_{SYMBOL}.png"
)

# %%
# --- choose a symbol & gather horizons ---
SYMBOL = "IRCTC"  # change as needed
r_1d = pd.read_pickle(DATA_INT/"log_returns_daily.pkl")[SYMBOL]
r_21 = pd.read_pickle(DATA_INT/"log_returns_trailing_w21.pkl")[SYMBOL]
r_63 = pd.read_pickle(DATA_INT/"log_returns_trailing_w63.pkl")[SYMBOL]
r_252 = pd.read_pickle(DATA_INT/"log_returns_trailing_w252.pkl")[SYMBOL]

qviz.plot_multi_tf_pdf(
    data={"1D": r_1d.dropna(), "21D": r_21.dropna(), "63D": r_63.dropna(), "252D": r_252.dropna()},
    title=f"{SYMBOL} — PDFs across horizons",
    show_kde=True, show_normal=False, show_student=False,
    save_path=FIG_DIR/f"pdf_{SYMBOL}.png"
)

# %%
# ZSCORE VISUALS

# %%
# returns that include your index:
r_1d_all = pd.read_pickle(DATA_INT / "log_returns_daily_all.pkl")
index_name = "NIFTY50"   # or read from your meta helper
symbol = "UJJIVANSFB"

# %%
# (A) Single snapshot for a stock
z21_stock = qviz.prepare_z_series(r_1d_all, symbol= symbol, window=21)
qviz.plot_z_pdf_snapshot(
    z21_stock, overlays=("kde","normal","t"),
    title=f"{symbol} — z distributions across windows",
    save_path=RUN_DIR / "figures" / "z_pdf_BAJFINANCE_21.png"
)
# Out:
# <AxesSubplot:title={'center':'UJJIVANSFB — z distributions across windows'}, xlabel='z', ylabel='density'>

# %%
# (B) Multi-timeframe overlay for the index
qviz.plot_z_pdf_multi_tf(
    r_1d_all, symbol=index_name,
    windows=(5,21,63,120,252),
    overlays=("kde"),         # keep uncluttered
    title=f"{index_name} — z distributions across windows",
    save_path=RUN_DIR / "figures" / f"z_pdf_multi_{index_name}.png"
)
# Out:
# <AxesSubplot:title={'center':'NIFTY50 — z distributions across windows'}, xlabel='z', ylabel='density'>
