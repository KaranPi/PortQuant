# %%
# --- Make local package importable (robust for notebooks in subfolders) ---
import sys
from pathlib import Path

def add_src_to_path(pkg="quantlib", levels_up=3):
    here = Path.cwd().resolve()
    candidates = [here / "src"]
    # also check parents: ../src, ../../src, ...
    for i in range(1, levels_up+1):
        candidates.append(here.parents[i-1] / "src")
    for p in candidates:
        if (p / pkg / "__init__.py").exists():
            sys.path.insert(0, str(p))
            print(f"[OK] Added to sys.path: {p}")
            return p
    raise FileNotFoundError("Could not find src/quantlib/__init__.py relative to this notebook.")

add_src_to_path()
# Out:
# [OK] Added to sys.path: C:\Users\quantbase\Desktop\quant\src
# WindowsPath('C:/Users/quantbase/Desktop/quant/src')

# %%
# --- bootstrap & config ---
import sys, pathlib; sys.path.append(str(pathlib.Path.cwd() / "src"))
from pathlib import Path
import pandas as pd
from quantlib import returns as qret

DATA_INT = Path(r"C:\Users\quantbase\Desktop\quant\data_int")

# %%
from pathlib import Path
print((Path.cwd() / "src" / "quantlib" / "__init__.py").exists())
print((Path.cwd().parent / "src" / "quantlib" / "__init__.py").exists())
# Out:
# False
# True

# %%
# --- load prices, compute returns, save ---
prices = pd.read_pickle(DATA_INT/"prices_close_anchor_leftjoin.pkl").sort_index()
r_1d = qret.log_returns(prices)
r_1d.to_pickle(DATA_INT/"log_returns_daily.pkl")
pack = qret.trailing_log_returns_pack(r_1d, [5,21,63,252], min_frac=1.0)
for w, dfw in pack.items():
    dfw.to_pickle(DATA_INT/f"log_returns_trailing_w{w}.pkl")
print("Saved daily & trailing returns.", r_1d.shape)
assert r_1d.notna().sum().sum() > 0
# Out:
# Saved daily & trailing returns. (856, 57)

# %%
r_pack = qret.trailing_log_returns_pack(r_1d, [1,3,5])

# %%
r_pack
# Out:
# {1:               ZOMATO       ACI  ADANIENT  ADANIPORTS  AEROFLEX    AETHER  \
#  date
#  2022-03-30       NaN       NaN       NaN         NaN       NaN       NaN
#  2022-03-31 -0.032868       NaN  0.009726    0.008822       NaN       NaN
#  2022-04-01  0.024011       NaN  0.014242    0.014808       NaN       NaN
#  2022-04-04  0.022868       NaN  0.010804    0.040896       NaN       NaN
#  2022-04-05 -0.027624       NaN  0.035194    0.035405       NaN       NaN
#  ...              ...       ...       ...         ...       ...       ...
#  2025-09-03  0.011411  0.011059  0.006356   -0.002848  0.030900  0.013449
#  2025-09-04  0.000460  0.001528 -0.004335   -0.003157 -0.022460 -0.014052
#  2025-09-05  0.008850  0.000364  0.001140   -0.004830  0.012528 -0.005313
#  2025-09-08  0.001518  0.003556  0.012848    0.019850  0.000617 -0.001687
#  2025-09-09 -0.012055 -0.003047  0.000303    0.023891 -0.016899  0.001148
#
#                AVALON  AXISBANK  BAJFINANCE  BANDHANBNK  ...    SWIGGY  \
#  date                                                    ...
#  2022-03-30       NaN       NaN         NaN         NaN  ...       NaN
#  2022-03-31       NaN  0.014157    0.001116    0.023701  ...       NaN
#  2022-04-01       NaN  0.017452    0.020201    0.041108  ...       NaN
#
#                AVALON  AXISBANK  BAJFINANCE  BANDHANBNK  ...    SWIGGY  \
#  date                                                    ...
#  2022-03-30       NaN       NaN         NaN         NaN  ...       NaN
#  2022-03-31       NaN       NaN         NaN         NaN  ...       NaN
#  2022-04-01       NaN       NaN         NaN         NaN  ...       NaN
#  2022-04-04       NaN  0.043864    0.032399    0.060272  ...       NaN
#  2022-04-05       NaN  0.028430    0.017545    0.025533  ...       NaN
#  ...              ...       ...         ...         ...  ...       ...
#  2025-09-03  0.038436  0.009048    0.020799    0.017947  ...  0.049632
#  2025-09-04  0.024558 -0.010512    0.049788    0.007041  ... -0.012682
#  2025-09-05  0.099664 -0.000284    0.051990    0.007991  ...  0.030291
#  2025-09-08  0.073028  0.000758    0.052169   -0.001154  ...  0.028729
#  2025-09-09  0.082747  0.001712    0.014497    0.006013  ...  0.031523
#
#               SYNGENE  TATACONSUM  TATAELXSI  TATAPOWER  UJJIVANSFB       VBL  \
#  date
#  2022-03-30       NaN         NaN        NaN        NaN         NaN       NaN
#  2022-03-31       NaN         NaN        NaN        NaN         NaN       NaN
#  2022-04-01       NaN         NaN        NaN        NaN         NaN       NaN
#  2022-04-04  0.025547    0.028639   0.001433   0.041533    0.178994 -0.008939
#  2022-04-05  0.027318    0.036935   0.004312   0.136669    0.223144  0.013978
#  ...              ...         ...        ...        ...         ...       ...
#  2025-09-03  0.040701    0.035952   0.036303   0.039308    0.008632  0.036481
#  2025-09-04  0.033518   -0.004285   0.013167   0.005372   -0.004629 -0.011880
#  2025-09-05  0.019860   -0.026138   0.004689  -0.000648   -0.011677 -0.061019
#  2025-09-08 -0.003688   -0.027726   0.007709  -0.015277    0.025684 -0.063741
#  2025-09-09 -0.018750    0.011510   0.022858   0.005344    0.096343 -0.031123
#
#               VINCOFE  WAAREERTL  WHIRLPOOL
#  date
#  2022-03-30       NaN        NaN        NaN
#  2022-03-31       NaN        NaN        NaN
#  2022-04-01       NaN        NaN        NaN
#  2022-04-04       NaN        NaN   0.034413
#  2022-04-05       NaN        NaN   0.063193
#  ...              ...        ...        ...
#  2025-09-03  0.013719   0.002829   0.033494
#  2025-09-04 -0.005031  -0.022000   0.024531
#  2025-09-05 -0.017722  -0.004027   0.017319
#  2025-09-08 -0.014883  -0.013436   0.013368
#  2025-09-09 -0.020101   0.022482   0.016026
#
#  [856 rows x 57 columns],
#  5:               ZOMATO       ACI  ADANIENT  ADANIPORTS  AEROFLEX    AETHER  \
#  date
#  2022-03-30       NaN       NaN       NaN         NaN       NaN       NaN
#  2022-03-31       NaN       NaN       NaN         NaN       NaN       NaN
#  2022-04-01       NaN       NaN       NaN         NaN       NaN       NaN
#  2022-04-04       NaN       NaN       NaN         NaN       NaN       NaN
#  2022-04-05       NaN       NaN       NaN         NaN       NaN       NaN
#  ...              ...       ...       ...         ...       ...       ...
#  2025-09-03  0.025467  0.046589  0.007323    0.012841  0.022631  0.026877
#  2025-09-04  0.033505  0.056239  0.001581    0.009684  0.018801  0.013437
#  2025-09-05  0.047280  0.046804  0.016217    0.006832  0.045314  0.007377
#  2025-09-08  0.026279  0.033440  0.011621    0.009689  0.020726 -0.001889
#  2025-09-09  0.010184  0.013459  0.016312    0.032906  0.004685 -0.006456
#
#                AVALON  AXISBANK  BAJFINANCE  BANDHANBNK  ...    SWIGGY  \
#  date                                                    ...
#  2022-03-30       NaN       NaN         NaN         NaN  ...       NaN
#  2022-03-31       NaN       NaN         NaN         NaN  ...       NaN
#  2022-04-01       NaN       NaN         NaN         NaN  ...       NaN
#  2022-04-04       NaN       NaN         NaN         NaN  ...       NaN
#  2022-04-05       NaN       NaN         NaN         NaN  ...       NaN
#  ...              ...       ...         ...         ...  ...       ...
#  2025-09-03  0.022907  0.004371    0.022624   -0.006836  ...  0.000116
#  2025-09-04 -0.000289 -0.001427    0.063943   -0.002766  ...  0.004976
#  2025-09-05  0.105306  0.010185    0.065848    0.009473  ...  0.069066
#  2025-09-08  0.097180 -0.005668    0.059953    0.019640  ...  0.033618
#  2025-09-09  0.115946 -0.003794    0.063443    0.008725  ...  0.024810
#
#               SYNGENE  TATACONSUM  TATAELXSI  TATAPOWER  UJJIVANSFB       VBL  \
#  date
#  2022-03-30       NaN         NaN        NaN        NaN         NaN       NaN
#  2022-03-31       NaN         NaN        NaN        NaN         NaN       NaN
#  2022-04-01       NaN         NaN        NaN        NaN         NaN       NaN
#  2022-04-04       NaN         NaN        NaN        NaN         NaN       NaN
#  2022-04-05       NaN         NaN        NaN        NaN         NaN       NaN
#  ...              ...         ...        ...        ...         ...       ...
#  2025-09-03  0.004767    0.022434  -0.009353   0.029732    0.006058 -0.006510
#  2025-09-04  0.042930    0.008156   0.016720   0.030518    0.015899 -0.016613
#  2025-09-05  0.035317    0.006549   0.040623   0.030662   -0.002581 -0.036584
#  2025-09-08  0.022342   -0.001395   0.020783   0.007070    0.019662 -0.043952
#  2025-09-09  0.013982   -0.015841   0.023318  -0.003633    0.097271 -0.050745
#
#               VINCOFE  WAAREERTL  WHIRLPOOL
#  date
#  2022-03-30       NaN        NaN        NaN
#  2022-03-31       NaN        NaN        NaN
#  2022-04-01       NaN        NaN        NaN
#  2022-04-04       NaN        NaN        NaN
#  2022-04-05       NaN        NaN        NaN
#  ...              ...        ...        ...
#  2025-09-03 -0.032714   0.001853   0.045561
#  2025-09-04 -0.006521  -0.020941   0.036066
#  2025-09-05 -0.001780  -0.007256   0.042451
#  2025-09-08 -0.009607  -0.025155   0.034560
#  2025-09-09 -0.032631   0.018258   0.027729
#
#  [856 rows x 57 columns]}

# %%
r_1d
# Out:
#               ZOMATO       ACI  ADANIENT  ADANIPORTS  AEROFLEX    AETHER  \
# date
# 2022-03-30       NaN       NaN       NaN         NaN       NaN       NaN
# 2022-03-31 -0.032868       NaN  0.009726    0.008822       NaN       NaN
# 2022-04-01  0.024011       NaN  0.014242    0.014808       NaN       NaN
# 2022-04-04  0.022868       NaN  0.010804    0.040896       NaN       NaN
# 2022-04-05 -0.027624       NaN  0.035194    0.035405       NaN       NaN
# ...              ...       ...       ...         ...       ...       ...
# 2025-09-03  0.011411  0.011059  0.006356   -0.002848  0.030900  0.013449
# 2025-09-04  0.000460  0.001528 -0.004335   -0.003157 -0.022460 -0.014052
# 2025-09-05  0.008850  0.000364  0.001140   -0.004830  0.012528 -0.005313
# 2025-09-08  0.001518  0.003556  0.012848    0.019850  0.000617 -0.001687
# 2025-09-09 -0.012055 -0.003047  0.000303    0.023891 -0.016899  0.001148
#
#               AVALON  AXISBANK  BAJFINANCE  BANDHANBNK  ...    SWIGGY  \
# date                                                    ...
# 2022-03-30       NaN       NaN         NaN         NaN  ...       NaN
# 2022-03-31       NaN  0.014157    0.001116    0.023701  ...       NaN
# 2022-04-01       NaN  0.017452    0.020201    0.041108  ...       NaN
# 2022-04-04       NaN  0.012254    0.011082   -0.004537  ...       NaN
# 2022-04-05       NaN -0.001276   -0.013738   -0.011038  ...       NaN
# ...              ...       ...         ...         ...  ...       ...
# 2025-09-03  0.032794 -0.001421    0.006941    0.016465  ...  0.010858
# 2025-09-04  0.000405 -0.004085    0.042004   -0.013753  ... -0.017571
# 2025-09-05  0.066465  0.005222    0.003044    0.005279  ...  0.037005
# 2025-09-08  0.006157 -0.000379    0.007120    0.007320  ...  0.009295
# 2025-09-09  0.010125 -0.003131    0.004332   -0.006585  ... -0.014776
#
#              SYNGENE  TATACONSUM  TATAELXSI  TATAPOWER  UJJIVANSFB       VBL  \
# date
# 2022-03-30       NaN         NaN        NaN        NaN         NaN       NaN
# 2022-03-31 -0.002340    0.014969  -0.017565  -0.012699   -0.016751 -0.020504
# 2022-04-01 -0.000502    0.015825   0.008185   0.028095    0.093466 -0.002553
# 2022-04-04  0.028389   -0.002155   0.010813   0.026137    0.102279  0.014119
# 2022-04-05 -0.000570    0.023265  -0.014686   0.082437    0.027399  0.002412
# ...              ...         ...        ...        ...         ...       ...
# 2025-09-03  0.025243    0.003265   0.000369   0.007998   -0.000464  0.012047
# 2025-09-04  0.007488   -0.030616   0.000092  -0.016975    0.001393 -0.031669
# 2025-09-05 -0.012872    0.001213   0.004228   0.008329   -0.012605 -0.041397
# 2025-09-08  0.001695    0.001677   0.003388  -0.006632    0.036896  0.009325
# 2025-09-09 -0.007573    0.008620   0.015241   0.003646    0.072052  0.000949
#
#              VINCOFE  WAAREERTL  WHIRLPOOL
# date
# 2022-03-30       NaN        NaN        NaN
# 2022-03-31       NaN        NaN  -0.003301
# 2022-04-01       NaN        NaN   0.019393
# 2022-04-04       NaN        NaN   0.018320
# 2022-04-05       NaN        NaN   0.025479
# ...              ...        ...        ...
# 2025-09-03 -0.002223   0.006058   0.008363
# 2025-09-04 -0.010306  -0.010282   0.003340
# 2025-09-05 -0.005193   0.000197   0.005616
# 2025-09-08  0.000616  -0.003351   0.004412
# 2025-09-09 -0.015525   0.025636   0.005998
#
# [856 rows x 57 columns]
